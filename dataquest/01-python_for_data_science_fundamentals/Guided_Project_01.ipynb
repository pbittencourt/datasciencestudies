# %% [markdown]
# # Perfis rentáveis de novos aplicativos para App Store e Google Play
#
# Nosso objetivo neste documento é encontrar perfis de aplicativos que sejam rentáveis para os mercados **App Store** e **Google Play**. Pensando no perfil de uma empresa que desenvolve aplicativos *iOS* e *Android*, nosso trabalho é auxiliar os desenvolvedores a tomarem boas decisões baseadas em dados a respeito dos tipos de aplicativos que eles desenvolverão.
#
# Neste perfil de empresa, são desenvolvidos principalmente aplicativos gratuitos, de forma que sua fonte de renda provém de publicidade dentro dos aplicativos. Deste modo, tem-se que a receita para este tipo de aplicativo é diretamente influenciada pelo número de usuários que o utiliza.
#
# Nosso objetivo com esse projeto, portanto, é analisar dados e auxiliar os desenvolvedores a entenderem quais tipos de aplicativos são mais propensos a atrairem usuários. Demonstraremos, ao longo deste documento, __ perfis promissores de aplicativos que valham a pena serem explorados para desenvolvimento:
#
# 1. Um aplicativo de finalidades práticas com princípios de *gameficação*.
#
# ## 1. Exploração de dados
#
# Destacamos, na etapa anterior, que nosso objetivo é ajudar desenvolvedores a entenderem quais tipos de aplicativos têm maiores chances de atrairem usuários na **Google Play** e na **App Store**. Para isto, precisamos coletar e analisar dados de aplicativos disponíveis nessas plataformas.
#
# Até setembro de 2018, havia aproximadamente 2 milhões de aplicativos *iOS* disponíveis da App Store e 2,1 milhões de aplicativos *Android* na Google Play.
#
# Coletar dados de cerca de 4 milhões de aplicativos requer uma quantidade significativa de tempo e de dinheiro. Para evitar o desperdício de recursos nesta coleta, devemos primeiro verificar se é possível obter dados relevantes de forma gratuita. Para nossa sorte, existem duas bases de dados que servem aos nossos objetivos:
#
# * Um [conjunto de dados](https://www.kaggle.com/lava18/google-play-store-apps) contendo informações de aproximadamente 10.000 aplicativos Android da Google Play. Esses dados foram coletados em agosto de 2018. Você pode baixá-los diretamente [deste link](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv).
# * Um [conjunto de dados](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps) contendo informações de aproximadamente 7.000 aplicativos iOS da App Store. Esses dados foram coletados em julho de 2017. Você pode baixá-los diretamente [deste link](https://dq-content.s3.amazonaws.com/350/AppleStore.csv).
#
# ### 1.1. Criando uma função para a leitura dos dados
#
# Começaremos abrindo esses dois conjuntos de arquivos. Para fins de reutilização, criamos uma função `open_dataset()`:

# %%
def open_dataset(file_name, header=True):
    opened_file = open(file_name, encoding='utf8')
    from csv import reader
    read_file = reader(opened_file)
    data = list(read_file)

    if header:
        return data[0], data[1:]
    else:
        return data

# %% [markdown]
# A função `open_dataset()`:
#
# * Recebe dois parâmetros:
#     * `file_name`, do tipo `string`, que indica o arquivo o conjunto de dados a ser analisado, no formato *csv*;
#     * `header`, do tipo `bool` e valor padrão `True`, que indica se o conjunto de dados possui ou não cabeçalho.
# * Abre o arquivo `file_name` através da função `open()` e atribui essa requisição à variável `opened_file`.
#     * O parâmetro `encoding='utf8'` codifica o arquivo no formato `Unicode UTF-8`.
# * Importa o módulo `reader` do pacote `csv`.
# * Lê o arquivo em `opened_file` através da função `reader()`, atribuindo os dados à variável `read_file`.
# * Transforma os conteúdos de `read_file` em uma lista, através da função `list()`, armazenando seu conteúdo na variável `data`.
# * Verifica se o conjunto de dados possui cabeçalho, retornando:
#     * uma tupla `(cabeçalho, conteúdo)`, em caso positivo;
#     * o conjunto completo de dados, em caso negativo.
#
# Com isto em mente, podemos abrir os arquivos `AppleStore.csv` e `googleplaystore.csv`, armazenando seus conteúdos nas variáveis `ios` e `android`, respectivamente:

# %%
ios_header, ios = open_dataset('AppleStore.csv')
android_header, android = open_dataset('googleplaystore.csv')

# %% [markdown]
# Convém notar que, na atribuição de valores às variáveis `ios` e `android`, aproveitamos o retorno da função `open_dataset()` para atribuirmos valores também às variáveis `ios_header` e `android_header`, contendo dos cabeçalhos desses conjuntos de dados.
#
# ### 1.2. Criando uma função para a exploração dos dados
#
# Para tornar mais fácil o trabalho de exploração desses dados, criamos uma função chamada `explore_data()` que pode ser utilizada para imprimir linhas de uma forma mais legível:

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
        
    if rows_and_columns:
        print('Número de linhas:', len(dataset))
        print('Número de colunas:', len(dataset[0]))

# %% [markdown]
# A função `explore_data()`:
#
# * Recebe quatro parâmetros:
#     * `dataset`, do tipo `list`, correspondente ao conjunto de dados que será explorado.
#     * `start` e `end`, do tipo `int`, correspondentes ao início e ao fim do fatiamento do conjunto de dados, respectivamente.
#     * `rows_and_columns`, do tipo `bool` e valor padrão `False`, que informa se exibiremos o número de linhas e de colunas do conjunto de dados.
# * Fatia o conjunto de dados utilizando a sintaxe `dataset[start:end]`.
# * Circula através do fatiamento e, para cada iteração, exibe uma linha do conjunto (`print(row)`), adicionando uma linha em branco em seguida (`print('\n')`), para fins de leitura.
# * Caso `rows_and_columns` for passado como `True`, exibe o número de linhas e de colunas do conjunto de dados.
#     * `dataset` não deve possuir uma linha de cabeçalho; caso contrário, a função retornará o número errado de linhas e de colunas (uma a mais comparado com o tamanho real).

# %% [markdown]
# Podemos, finalmente, explorar esses conjuntos de dados na tentativa de extrair informações relevantes. Comecemos com a base de dados dos aplicativos *Android* na **Google Play Store**, exibindo o cabeçalho e os três primeiros aplicativos que aparecem na lista:

# %%
print(android_header)
print('-' * 30)
explore_data(android, 0, 3, True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ------------------------------
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Número de linhas: 10841
# Número de colunas: 13

# %% [markdown]
# Nota-se que este conjunto de dados possui 10.841 aplicativos e suas 13 colunas exibem informações a respeito de cada aplicativo. Para nossa análise, as categorias `'Category'`, `'Rating'`, `'Reviews'`, `'Installs` e `'Price'` parecem ser as mais relevantes.
#
# Vejamos agora a base de dados de aplicativos *iOS* na **Apple Store**:

# %%
print(ios_header)
print('-' * 30)
explore_data(ios, 0, 3, True)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
# ------------------------------
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Número de linhas: 7197
# Número de colunas: 16

# %% [markdown]
# Nota-se que este conjunto de dados possui 7.197 aplicativos e 16 colunas descritivas. Em nossa análise, estamos interessados nos campos `'price'`, `'rating_count_tot'`, `'user_rating'` e `'prime_genre'`. À primeira vista, nem todos os campos são auto-explicativos, então uma visita à [documentação](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/) pode ser útil.

# %% [markdown]
# ## 2. Remoção de dados incorretos
#
# No passo anterior, abrimos os dois conjuntos de dados e exploramos brevemente seu conteúdo. Antes de iniciarmos nossa análise, precisamos nos certificar de que os dados que iremos analisar estão corretos, para não corrermos riscos de emitir juízos incorretos a respeito da base de dados.
#
# Em [uma das publicações](https://www.kaggle.com/lava18/google-play-store-apps/discussion/66015) do fórum de discussão do *Google Play Dataset* há a menção de que a linha 10472 possui um erro. Vamos exibí-la e compará-la com o cabeçalho e com outra linha qualquer (supostamente correta):

# %%
print(android[10472])  # linha incorreta
print('\n')
print(android_header)  # cabeçalho
print('\n')
print(android[7000])  # uma linha correta qualquer
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['PixPanda - Color by Number Pixel Art Coloring Book', 'FAMILY', '4.9', '55723', '14M', '1,000,000+', 'Free', '0', 'Everyone', 'Entertainment', 'June 4, 2018', '3.3', '4.0.3 and up']

# %% [markdown]
# Caso ainda não tenha ficado claro, utilizaremos a função `len()` para exibir a quantidade e itens em cada uma dessas linhas:

# %%
print(len(android[10472]))
print(len(android_header))
print(len(android[77]))
# Out:
# 12
# 13
# 13

# %% [markdown]
# Verifica-se, assim, que a linha 10472 possui uma coluna a menos. Analisando item a item, percebe-se que está faltando o item `'Category'`. Como isto compromete nossa análise de dados, uma vez que os valores das colunas são todos deslocados para a esquerda, utilizaremos a declaração `del` para remover essa linha do dataset:

# %%
# exibe a quantidade de registros antes de deletar a linha 10472
print(len(android))

# deleta a linha 10472
del android[10472]

# exibe a quantidade de registros após de deletar a linha 10472
print(len(android))
# Out:
# 10841
# 10840

# %% [markdown]
# ## 3. Remoção de dados duplicados
#
# Explorando a base de dados dos aplicativos *Android*, percebemos que, para alguns deles, há entradas duplicadas. No caso, por exemplo, do aplicativo **Instagram**:

# %%
for app in android:
    name = app[0]
    if name == 'Instagram':
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# Devemos procurar pela ocorrência de entradas duplicadas em toda nossa base de dados. Para isto, criaremos duas listas: `duplicate_apps`, que armazenará os nomes dos aplicativos duplicados e `unique_apps`, para armazenar os nomes dos aplicativos únicos. Dentro do *loop* no dataset `android`:
#
# * Atribuiremos à variável `name` o nome do aplicativo.
# * Verificaremos se `name` aparece na lista `unique_apps`.
#     * Em caso afirmativo, temos que a ocorrência de `name` não é nova, então devemos adicionar `name` à lista `duplicate_apps`.
#     * Em caso negativo, adicionaremos `name` à lista `unique_apps`, uma vez que se trata de ocorrência inédita.
#
# Ao final deste processo, exibiremos, para fins de comparação, as quantidades de aplicativos únicos e de aplicativos duplicados, bem como alguns registros deste último caso:

# %%
duplicate_apps = []
unique_apps = []  

for app in android:
    name = app[0]
    if name in unique_apps:
        duplicate_apps.append(name)
    else:
        unique_apps.append(name)
        
print('Número de aplicativos únicos:', len(unique_apps))
print('Número de aplicativos duplicados:', len(duplicate_apps))
print('Exemplos de aplicativos duplicados:', duplicate_apps[:10])
# Out:
# Número de aplicativos únicos: 9659
# Número de aplicativos duplicados: 1181
# Exemplos de aplicativos duplicados: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack']

# %% [markdown]
# Através dessa análise, observamos que existem 1.181 aplicativos duplicados no dataset `android`. Entretanto, não podemos removê-los a esmo, de forma aleatória, sob pena de comprometermos nossa análise.
#
# Voltemos novamente ao caso do aplicativo **Instagram**. Fazendo um laço pelos aplicativos da lista `android`, armazenaremos valores duplicados em outra lista, aqui nomeada `instagram`:

# %%
instagram = []
for app in android:
    name = app[0]
    if name == 'Instagram':
        instagram.append(app)

# %% [markdown]
# Pensando em utilizações futuras ao longo deste projeto, definiremos duas novas funções: `extract()` e `are_unique()`:
#
# * A função `extract()`:
#     * Tem por objetivo extrair uma única coluna de um conjunto de dados (dataset).
#     * Recebe como parâmetros
#         * `dataset`, o conjunto de dados, que se supõe ser uma lista de listas;
#         * `index`, um número inteiro, referente ao índice da coluna de `dataset` que se pretende extrair.
#     * Retorna uma lista com os dados da coluna extraída.
#
# * A função `are_unique()`:
#     * Tem por objetivo comparar os valores de uma lista.
#     * Recebe `column` como parâmetro, referente à lista cuja unicidade se pretende verificar
#     * Retorna `True` caso todos os valores da lista sejam iguais ou `False`, caso a lista apresente algum valor diferente dos outros.

# %%
def extract(dataset, column_index=0):
    column = []
    for row in dataset:
        column.append(row[column_index])
    return column

def are_unique(column):
    unique = []
    duplicate = []

    for value in column:
        if value in unique:
            duplicate.append(value)
        else:
            unique.append(value)

    return True if len(unique) == 1 else False

# %% [markdown]
# Comparemos os valores da lista `instagram`, a partir da utilização das funções acima definidas:

# %%
for i in range(0, len(instagram[0])):
    column = extract(instagram, i)
    if not are_unique(column):
        print('Found different values in column', i)
        print(column)
# Out:
# Found different values in column 3
# ['66577313', '66577446', '66577313', '66509917']

# %% [markdown]
# Percebe-se que a única diferença entre os registros se dá na coluna de índice `3`, correspondente aos `'Reviews'` dos aplicativos. Isto ocorre, possivelmente, porque os dados foram coletados em diferentes horários do dia (note-se que todos eles se referem ao mesmo dia, 31 de julho de 2018, mas não há menção aos horários de coleta).
#
# Assumiremos então que, quanto maior o número de reviews, mais recente é o registro. Preservaremos, então, o registro com o maior número de reviews, removendo as outras entradas para o mesmo aplicativo.
#
# ### 3.1. Coletando o número máximo de reviews
#
# Para remover entradas duplicadas, iniciaremos criando o dicionário `reviews_max`, no qual a chave (*key*) corresponderá ao nome do aplicativo e o valor (*value*) corresponderá ao maior número de reviews daquele aplicativo. Com o dicionário criado, faremos um laço pelo *dataset* `android` e, a cada iteração:
#
# * Atribuiremos à variável `name` o nome do aplicativo.
# * Atribuiremos à variável `n_reviews` o número de reviews do aplicativo, já convertido para o tipo `float`.
# * Verificaremos se `name` já existe em `reviews_max` e se `reviews_max[name] < n_reviews`. Em caso afirmativo, atribuiremos a `reviews_max[name]` o valor de `n_reviews`.
# * Verificaremos se `name` não existe como uma chave em `reviews_max`. Em caso afirmativo, criaremos uma nova entrada `reviews_max[name]`, atribuindo a ela o valor de `n_reviews`.
#     * É importante que este comando não venha como uma cláusula `else` da declaração anterior, sob pena de ocorrer mesmo que `reviews_max[name] < n_reviews` seja avaliada como `False`.
#
# Ao final do loop, exibiremos a quantidade de registros em `reviews_max`, comparando-a com o valor esperado:

# %%
reviews_max = {}
for app in android:
    name = app[0]
    n_reviews = float(app[3])

    if name in reviews_max and reviews_max[name] < n_reviews:
        reviews_max[name] = n_reviews
    elif name not in reviews_max:
        reviews_max[name] = n_reviews

print('Expected lenght:', len(unique_apps))
print('Lenght found:', len(reviews_max))
if len(unique_apps) == len(reviews_max):
    print('''So far so good!''')
# Out:
# Expected lenght: 9659
# Lenght found: 9659
# So far so good!

# %% [markdown]
# ### 3.2. Limpando entradas duplicadas
#
# Com o dicionário `reviews_max` criado e funcionando da forma esperada, podemos passar para a remoção dos dados duplicados.
#
# Iniciaremos criando duas listas, `android_clean` e `already_added`. A primeira armazenará o nosso *dataset* limpo, ou seja, sem as entradas duplicadas, enquanto que a segunda armazenará apenas os nomes dos aplicativos cujas ocorrências forem previamente detectadas.
#
# Feito isto, faremos um loop pelo *dataset* `android` e, a cada iteração:
#
# * Atribuiremos à variável `name` o nome do aplicativo.
# * Atribuiremos à variável `n_reviews` o número de reviews do aplicativo, já convertido para o tipo `float`.
# * Verificaremos se `n_reviews` tem o mesmo valor de `reviews_max[name]` e se `name` não se encontra na lista `already_added`.
#     * Em caso afirmativo:
#         * adicionamos a linha `app` inteira à lista `android_clean`;
#         * adicionamos `name` à lista `already_added`.
#
# Para fins de verificação, compareremos o tamanho de `android_clean` com o valor obtido no passo anterior:

# %%
android_clean = []
already_added = []

for app in android:
    name = app[0]
    n_reviews = float(app[3])

    if n_reviews == reviews_max[name] and name not in already_added:
        android_clean.append(app)
        already_added.append(name)

print(len(android_clean))
# Out:
# 9659

# %% [markdown]
# ## 4. Remoção de aplicativos em outros idiomas
#
# Estamos trabalhando com um perfil de empresa que desenvolve aplicativos em inglês, então precisamos segmentar nosso conjunto de dados pensando em usuários falantes deste idioma.
#
# Uma análise mais aprofundada nos conjuntos de dados `android` e `ios` mostra aplicativos que não estão de acordo com esses parâmetros:

# %%
print('iOS apps:')
print(ios[813][1])
print(ios[6731][1])
print('\nAndroid apps:')
print(android_clean[4412][0])
print(android_clean[7940][0])
# Out:
# iOS apps:
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# 【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜
#
# Android apps:
# 中国語 AQリスニング
# لعبة تقدر تربح DZ

# %% [markdown]
# ### 4.1. Criando uma função para verificação de caracteres
#
# Como não estamos interessados neste tipo de aplicativo, removeremos-os das listas. Para tanto, criaremos uma função `is_english()`, que recebe uma string como parâmetro e verifica, através da função `ord()`, se ela contém apenas caracteres que são utilizados na língua inglesa.
#
# A [função](https://docs.python.org/3/library/functions.html#ord) `ord()` retorna, para um dado caracter recebido, seu correspondente código [ASCII](https://en.wikipedia.org/wiki/ASCII). Os números correspondentes aos caracteres que são comumente utilizados em inglês estão no intervalo 0 a 127. Deste modo, nossa função `is_english()` deve retornar `True` se todos os caracteres do argumento passado estiverem dentro deste intervalo ou `False` se algum caracteres fora deste intervalo for encontrado:

# %%
def is_english(text):
    for char in text:
        if ord(char) > 127:
            return False
    return True

# %% [markdown]
# Verificaremos seu funcionamento com alguns nomes de aplicativos:

# %%
some_apps = [
    'Instagram', 
    '爱奇艺PPS -《欢乐颂2》电视剧热播', 
    'Docs To Go™ Free Office Suite', 
    'Instachat 😜'
]
for app in some_apps:
    print(app)
    print(is_english(app))
# Out:
# Instagram
# True
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# False
# Docs To Go™ Free Office Suite
# False
# Instachat 😜
# False

# %% [markdown]
# Nossa função funciona *parcialmente* bem, uma vez que, apesar de detectar que o segundo item da lista (`'爱奇艺PPS -《欢乐颂2》电视剧热播'`) não pertence à lingua inglesa, deixa de fora do intervalo especificado alguns símbolos (`'™'`) e emojis (`'😜'`). Se for utilizada deste modo, provavelmente removeremos de nossos conjuntos de dados vários aplicativos úteis para nossa análise.

# %% [markdown]
# ### 4.2. Refinando a função para verificação de caracteres
#
# No bloco anterior vimos que os aplicativos `'Docs To Go™ Free Office Suite'` e `'Instachat 😜'` não passaram pelo crivo da função. Isto ocorre porque os códigos ASCII correspondentes ao símbolo ™ e ao emoji 😜 estão fora do intervalo que especificamos (0 a 127):

# %%
print(ord('™'))
print(ord('😜'))
# Out:
# 8482
# 128540

# %% [markdown]
# Definir todos os possíveis caracteres contendo símbolos e emojis que podem aparecer nos nomes dos aplicativos pode se mostrar uma tarefa infrutífera e inglória, consumindo um tempo demasiadamente extenso. Em contrapartida, se utilizarmos a função tal como foi definida, removeremos aplicativos importantes de nossa base de dados.
#
# Para minimizar os efeitos de uma possível perda de dados, apenas removeremos de nossos *datasets* aplicativos cujos nomes contenham mais do que **três caracteres** com códigos ASCII fora do intervalo especificado. Em outras palavras, nomes com até três caracteres correspondendo a símbolos ou emojis *ainda* serão classificados como pertencentes à língua inglesa. Essa escolha arbitrária pode não ser perfeita mas ainda nos parece boa o suficiente para nossos propósitos classificatórios.
#
# Modificaremos, então, nossa função `is_english()`, adicionando um contador `c`, de valor inicialmente igual a zero, antes do *loop* pelos caracteres da string `text`. Para cada ocorrência de um caracter fora do intervalo ASCII 0-127, a variável `c` é incrementada em uma unidade. Ao final do laço, a função retorna `True` se o valor de `c` for igual ou inferior a 3 ou `False` em caso contrário:

# %%
def is_english(text):
    c = 0
    for char in text:
        if ord(char) > 127:
            c += 1
    return True if c <= 3 else False

# %% [markdown]
# Podemos, então, utilizar mais uma vez a lista `some_apps` para verificar se, agora, nossa função funciona como esperado:

# %%
some_apps = [
    'Instagram', 
    '爱奇艺PPS -《欢乐颂2》电视剧热播', 
    'Docs To Go™ Free Office Suite', 
    'Instachat 😜'
]
for app in some_apps:
    print(app)
    print(is_english(app))
# Out:
# Instagram
# True
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# False
# Docs To Go™ Free Office Suite
# True
# Instachat 😜
# True

# %% [markdown]
# Verificando-se que a função está de acordo com nossa proposta, passaremos agora para filtragem dos conjuntos de dados `ios` e `android_clean`. Faremos um laço em cada um dos conjuntos, adicionando a linha correspondente a uma lista separada caso o nome do aplicativo seja identificado como pertencente à língua inglesa:

# %%
android_english = []
for app in android_clean:
    name = app[0]
    if is_english(name):
        android_english.append(app)

print('Number of android english apps:', len(android_english))

ios_english = []
for app in ios:
    name = app[1]
    if is_english(name):
        ios_english.append(app)

print('Number of ios english apps:', len(ios_english))
# Out:
# Number of android english apps: 9614
# Number of ios english apps: 6183

# %% [markdown]
# Verificamos, assim, que nossos conjuntos de dados agora possuem **9.614** aplicativos *Android* e **6.183** aplicativos *iOS*. Podemos utilizar a função `explore_data()` para analisar alguns destes valores:

# %%
explore_data(android_english, 0, 3, True)
print('\n')
explore_data(ios_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Número de linhas: 9614
# Número de colunas: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ...

# %% [markdown]
# ## 5. Seleção de aplicativos gratuitos
#
# Como mencionado no início deste documento, nosso interesse está exclusivamente em aplicativos gratuitos de ambas as lojas. Deste modo, finalizando nosso processo de limpeza dos dados, isolaremos aplicativos pagos e não pagos em listas separadas.
#
# Criaremos as listas `android_final` e `ios_final`, armazenando nelas somente os aplicativos gratuitos das respectivas lojas. Para isto, basta realizar um laço nos *datasets* `android_english` e `ios_english` e, a cada iteração, verificar se o preço do aplicativo é igual a zero. Em caso afirmativo, adicionaremos a linha correspondente ao aplicativo à lista final:

# %%
android_final = []
for app in android_english:
    price = app[7]
    if price == '0':
        android_final.append(app)
print('Number of Android free apps:', len(android_final))

ios_final = []
for app in ios_english:
    price = app[4]
    if price == '0.0':
        ios_final.append(app)
print('Number of iOS free apps:', len(ios_final))
# Out:
# Number of Android free apps: 8864
# Number of iOS free apps: 3222

# %% [markdown]
# ## 6. Categorias de aplicativos mais comuns
#
# Como mencionado na introdução deste documento, nosso objetivo é determinar os tipos de aplicativos que atraem mais usuários, uma vez que nossa receita está diretamente relacionada com o número de pessoas que utilizam os aplicativos.
#
# Deste modo, uma possível estratégia para a validação de uma ideia de um aplicativo se daria em três passos:
#
# 1. Construir uma versão inicial do aplicativo *Android* e adicioná-la à loja **Google Play**.
# + Se o aplicativo obtiver uma boa resposta dos usuários, podemos continuar com seu desenvolvimento.
# + Caso o aplicativo continue rentável após seis meses, desenvolvemos uma versão iOS do mesmo e adicionamos à App Store.
#
# Nosso objetivo final é possuir um aplicativo em ambas as lojas, então precisamos encontrar perfis que se adequem a estes dois ambientes. Para tanto, precisamos analisar quais são as categorias de aplicativos mais comuns em nossos dois conjuntos de dados.
#
# ### 6.1. Criando funções para gerar e exibir tabelas de frequências
#
# Vamos iniciar definindo uma função `freq_table()` que gera, a partir de uma lista simples, um dicionário contendo, como chave, um item da lista e, como valor, uma lista contendo a quantidade de ocorrências deste item na lista (frequência absoluta) e a divisão deste pelo número total de registros (frequência relativa):

# %%
def freq_table(column):
    frequency_table = {}
    total = len(column)

    for row in column:
        if row in frequency_table:
            frequency_table[row][0] += 1
            frequency_table[row][1] = frequency_table[row][0] / total
        else:
            frequency_table[row] = []
            frequency_table[row].append(1)
            frequency_table[row].append(1 / total)
    return frequency_table

# %% [markdown]
# O que a função faz, essencialmente, é percorrer toda a lista `column` passada como parâmetro e, a cada iteração, verificar se o atual item, representado por `row`, se encontra no dicionário `frequency_table`, criado no início da definição da função, antes do laço de repetição.
#
# * Caso detectar que o item `row` já se encontra no dicionário, incrementa o valor do primeiro item de sua lista (*frequência absoluta*) em 1 unidade e atualiza o próximo item (*frequência relativa*) para receber a divisão do valor anterior por `total` (referente à quantidade total de registros).
# * Em caso contrário, cria um novo item em `frequency_table`, de chave `row` e do tiplo `list`.
#     * Adiciona um item à lista criada, que recebe o valor `1`, referente à frequência absoluta deste item.
#     * Adiciona outro item à lista, atribuindo a ele a divisão entre o valor `1` e o valor armazenado em `total`, referente à frequência relativa deste item.

# %% [markdown]
# Nosso próximo passo é criar uma função para a exibição das tabelas de frequências, uma vez que o código é rotineiro e será utilizado mais vezes ao longo deste projeto.

# %%
def display_freq_table(column, title='frequency table', size=50, sep='-'):
    # import module to sort dictionary by item value, instead by item key
    from operator import itemgetter
    # generates a frequency table from 'column' values
    ft = freq_table(column)
    # sort 'ft' by item values
    sort_ft = sorted(ft.items(), key=itemgetter(1), reverse=True)

    # prints a header showing this frequency table title
    print(sep * size)
    print(title.upper().center(size))
    print('(column | number of apps | % of total)'.center(size))
    print(sep * size)

    for value in sort_ft:
        # the google play dataset contains '_' separating words, so we should remove them
        name = value[0].replace("_", " ")
        # fetch absolute and relative frequencies and print them in a tabular way
        abs_fq = value[1][0]
        rel_fq = value[1][1] * 100
        print('{:34.34}  {:>6}  {:04.2f}%'.format(name, abs_fq, rel_fq))

    print(sep * size)

# %% [markdown]
# A função `display_freq_table()`:
#
# * Recebe como parâmetro obrigatório a lista `column`, a partir do qual será gerada uma tabela de frequências através da função `freq_table()`.
# * Possui, como parâmetros opcionais (apenas para fins de leitura):
#     * Uma string `title`, de valor padrão `'frequency table'`, referente ao título dessa tabela.
#     * Um inteiro `size`, de valor padrão `50`, correspondente à largura da tabela.
#     * Um caracter `sep`, de valor padrão `'-'`, para imprimir linhas horizontais separando seções da tabela.

# %% [markdown]
# ### 6.2. Análise dos aplicativos da Google Play
#
# Podemos, assim, utilizar a função `display_freq_table()` para inspecionar nossos conjuntos de dados. Comecemos com os aplicativos *Android*, do dataset `android_final`, para a coluna `'Category'` (índice `1`):

# %%
display_freq_table(extract(android_final, 1), 'android apps, by category')
# Out:
# --------------------------------------------------
#             ANDROID APPS, BY CATEGORY
#       (column | number of apps | % of total)
# --------------------------------------------------
# FAMILY                                1676  18.91%
# GAME                                   862  9.72%
# TOOLS                                  750  8.46%
# BUSINESS                               407  4.59%
# LIFESTYLE                              346  3.90%
# PRODUCTIVITY                           345  3.89%
# FINANCE                                328  3.70%
# MEDICAL                                313  3.53%
# SPORTS                                 301  3.40%
# PERSONALIZATION                        294  3.32%
# COMMUNICATION                          287  3.24%
# HEALTH AND FITNESS                     273  3.08%
# PHOTOGRAPHY                            261  2.94%
# NEWS AND MAGAZINES                     248  2.80%
# SOCIAL                                 236  2.66%
# ...

# %% [markdown]
# A maior parte dos aplicativos (quase 28%) está dentro das categorias `'Family'` e `'Games'`. Também pode-se perceber uma grande presença de aplicativos destinados a finalidades práticas, tais como `'Tools'`, `'Business'`, `'Lifestyle'` e `'Productivity'`. Uma análise mais profunda na categoria `'Family'` nos mostra que boa parte destes aplicativos se refere a jogos destinados a crianças.

# %%
for app in android_final:
    genre = app[1]
    if genre == 'FAMILY':
        print(app[0])
# Out:
# Jewels Crush- Match 3 Puzzle
# Coloring & Learn
# Mahjong
# Super ABC! Learning games for kids! Preschool apps
# Toy Pop Cubes
# Educational Games 4 Kids
# Candy Pop Story
# Princess Coloring Book
# Hello Kitty Nail Salon
# Candy Smash
# Happy Fruits Bomb - Cube Blast
# Princess Adventures Puzzles
# Kids Educational Game 3 Free
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# Coloring book moana
# Baby Panda Care
# Kids Educational :All in One
# Number Counting games for toddler preschool kids
# Learn To Draw Glow Flower
# No. Color - Color by Number, Number Coloring
# Draw.ly - Color by Number Pixel Art Coloring
# Baby puzzles
# Garden Fruit Legend
# Barbie™ Fashion Closet
# Candy Day
# Learn To Draw Glow Princess
# ABC Kids - Tracing & Phonics
# Barbie Magical Fashion
# Minion Rush: Despicable Me Official Game
# Piano Kids - Music & Songs
# Educational Games for Kids
# No.Draw - Colors by Number 2018
# Fruit Boom
# Baby Tiger Care - My Cute Virtual Pet Friend
# Rhythm Patrol
# ...

# %% [markdown]
# Ainda no dataset `android_final`, podemos comparar os dados da coluna `'Category'` com a análise da coluna `'Genre'` (índice `9`):

# %%
display_freq_table(extract(android_final, 9), 'android apps, by genre')
# Out:
# --------------------------------------------------
#               ANDROID APPS, BY GENRE
#       (column | number of apps | % of total)
# --------------------------------------------------
# Tools                                  749  8.45%
# Entertainment                          538  6.07%
# Education                              474  5.35%
# Business                               407  4.59%
# Lifestyle                              345  3.89%
# Productivity                           345  3.89%
# Finance                                328  3.70%
# Medical                                313  3.53%
# Sports                                 307  3.46%
# Personalization                        294  3.32%
# Communication                          287  3.24%
# Action                                 275  3.10%
# Health & Fitness                       273  3.08%
# Photography                            261  2.94%
# News & Magazines                       248  2.80%
# ...

# %% [markdown]
# Esses dados parecem confirmar a análise feita anteriormente. Ao que tudo indica, apesar das colunas `'Category'` e `'Genre'` serem similares, esta última parece ser mais granular, isto é, possui mais categorias (poderíamos chamá-las de *subcategorias*, o que parece ser aplicável, por exemplo, para o caso de jogos, que possuem classificações como *Ação*, *Aventura*, *Esporte*, etc.)
#
# ### 6.3. Análise dos aplicativos da App Store
#
# Analisemos agora a coluna `'prime_genre'`, índice `11` do dataset  `ios_final`:

# %%
display_freq_table(extract(ios_final, 11), 'iOS apps, by genre')
# Out:
# --------------------------------------------------
#                 IOS APPS, BY GENRE
#       (column | number of apps | % of total)
# --------------------------------------------------
# Games                                 1874  58.16%
# Entertainment                          254  7.88%
# Photo & Video                          160  4.97%
# Education                              118  3.66%
# Social Networking                      106  3.29%
# Shopping                                84  2.61%
# Utilities                               81  2.51%
# Sports                                  69  2.14%
# Music                                   66  2.05%
# Health & Fitness                        65  2.02%
# Productivity                            56  1.74%
# Lifestyle                               51  1.58%
# News                                    43  1.33%
# Travel                                  40  1.24%
# Finance                                 36  1.12%
# ...

# %% [markdown]
# Pode-se perceber que mais da metade dos aplicativos em inglês da App Store são jogos, correspondendo a aproximadamente 58% do total. Em seguida *Entretenimento*, *Foto e Vídeo*, *Educação* e *Redes sociais* representam quase 20% do restante.
#
# A impressão geral é que a **App Store** (pelo menos a parte que contém aplicativos gratuitos em inglês) é dominada por aplicativos criados para divertimento (jogos, entretenimento, foto e vídeo, redes sociais, esportes, música etc.), enquanto que aplicativos com finalidades mais práticas (educação, compras, serviços públicos, produtividade, estilo de vida etc.) são mais raros.
#
# No entanto, o fato de os aplicativos para diversão serem os mais numerosos também não implica que eles tenham também o maior número de usuários - a demanda pode não ser a mesma que a oferta.
#
# O cenário parece bastante diferente na **Google Play**: não existem muitos aplicativos projetados para diversão e parece que um bom número de aplicativos é projetado para fins práticos (família, ferramentas, negócios, estilo de vida, produtividade etc.). Entretanto, como já mencionamos, dentro da categoria *Família* há um grande número de jogos destinados a crianças pequenas.
#
# Com base nessas informações, podemos dizer que um aplicativo voltado a finalidades práticas (de produtividade, por exemplo) baseado em princípios de gameficação possa constituir um perfil que venha a obter bom desempenho em ambos os mercados.
#
# Passemos agora a investigar quais tipos de aplicativos possuem maior número de usuários.
#
# ## 7. Aplicativos mais populares, por gênero
#
# Uma maneira de encontrar os aplicativos mais populares das lojas é calcular o número médio de instalações para cada gênero de aplicativo. No conjunto de dados do *Google Play* podemos encontrar essa informação na coluna `'Installs'`, mas não há essa informação no conjunto de dados da *App Store*. Para contonar esse problema, utilizaremos como parâmetro de análise o número total de classificações de usuários, informado pela coluna `'rating_count_tot'`.
#
# ### 7.1. Análise de aplicativos da App Store
#
# Iniciemos, então, pela análise dos dados em `ios_final`. Abaixo, calcularemos a nota média para cada categoria de aplicativos na *App Store*:

# %%
# extracts genres from ios dataset and generates a freq. table from it
genres_ios = freq_table(extract(ios_final, -5))

# initialize an empty list which will contain all average ratings
genres_list = list()

# main loop: loop through each genre in genres list
for genre in genres_ios:

    total = 0  # total number of ratings
    len_genre = 0  # total number of apps

    # secondary loop: now, loop through all apps in ios dataset
    for app in ios_final:

        # fetch the genre of this app
        genre_app = app[-5]

        # check if this genre is the same as the genre of the main loop
        if genre_app == genre:

            # fetch the no. of ratings of this app
            n_ratings = float(app[5])

            # increase total of ratings and number of apps
            total += n_ratings
            len_genre += 1

    # calculates the average rating
    avg_ratings = total / len_genre

    # append tuple(ratings, genre) to genres_list
    # this awkward order will be useful to simplify sorting
    tuple_ratings_genre = (avg_ratings, genre)
    genres_list.append(tuple_ratings_genre)

# print list of genres, sorted descending by avg rating
for key in sorted(genres_list, reverse=True):
    print('{}: {:.2f}'.format(key[1], key[0]))
# Out:
# Navigation: 86090.33
# Reference: 74942.11
# Social Networking: 71548.35
# Music: 57326.53
# Weather: 52279.89
# Book: 39758.50
# Food & Drink: 33333.92
# Finance: 31467.94
# Photo & Video: 28441.54
# Travel: 28243.80
# Shopping: 26919.69
# Health & Fitness: 23298.02
# Sports: 23008.90
# Games: 22788.67
# News: 21248.02
# Productivity: 21028.41
# Utilities: 18684.46
# Lifestyle: 16485.76
# Entertainment: 14029.83
# Business: 7491.12
# Education: 7003.98
# Catalogs: 4004.00
# Medical: 612.00

# %% [markdown]
# Percebe-se que, em média, aplicativos da categoria `'Navigation'` se saem melhor do que os outros. Isto se deve à influência de aplicativos como *Waze* e *Google Maps* que, combinados, possuem quase **meio milhão** de classificações de usuários:

# %%
nav_apps = 0  # number of apps in category
nav_ratings = 0  # total of app ratings in category

for app in ios_final:
    if app[-5] == 'Navigation':
        nav_apps += 1
        nav_ratings += float(app[5])
        print(app[1], ':', app[5])

print('\nTotal number of \"Navigation\" apps:', nav_apps)
print('Total number of \"Navigation\" ratings:', nav_ratings)
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Google Maps - Navigation & Transit : 154911
# Geocaching® : 12811
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5
#
# Total number of "Navigation" apps: 6
# Total number of "Navigation" ratings: 516542.0

# %% [markdown]
# O mesmo padrão se aplica às categorias `'Social Networking'`, influenciada por gigantes como *Facebook*, *Pinterest* e *Skype for iPhone*, e `'Music'`, na qual grandes *players* de mercado, tais como *Spotify*, *Pandora* e *Shazam*, contribuem para um maior número de avaliações.

# %%
social_apps = []
social_ratings = 0

for app in ios_final:
    if app[-5] == 'Social Networking':
        social_ratings += float(app[5])
        string_to_append = app[1] + ': ' + app[5]
        social_apps.append(string_to_append)

print('Total number of \"Social Networking\" apps:', len(social_apps))
print('Total number of \"Social Networking\" ratings:', social_ratings)
print('Top \"Social Networking\" apps:')
print(social_apps[0:15])

print('-' * 30)

music_apps = []
music_ratings = 0

for app in ios_final:
    if app[-5] == 'Music':
        music_ratings += float(app[5])
        string_to_append = app[1] + ': ' + app[5]
        music_apps.append(string_to_append)

print('Total number of \"Music\" apps:', len(music_apps))
print('Total number of \"Music\" ratings:', music_ratings)
print('Top \"Music\" apps:')
print(music_apps[0:15])
# Out:
# Total number of "Social Networking" apps: 106
# Total number of "Social Networking" ratings: 7584125.0
# Top "Social Networking" apps:
# ['Facebook: 2974676', 'Pinterest: 1061624', 'Skype for iPhone: 373519', 'Messenger: 351466', 'Tumblr: 334293', 'WhatsApp Messenger: 287589', 'Kik: 260965', 'ooVoo – Free Video Call, Text and Voice: 177501', 'TextNow - Unlimited Text + Calls: 164963', 'Viber Messenger – Text & Call: 164249', 'Followers - Social Analytics For Instagram: 112778', 'MeetMe - Chat and Meet New People: 97072', 'We Heart It - Fashion, wallpapers, quotes, tattoos: 90414', 'InsTrack for Instagram - Analytics Plus More: 85535', 'Tango - Free Video Call, Voice and Chat: 75412']
# ------------------------------
# Total number of "Music" apps: 66
# Total number of "Music" ratings: 3783551.0
# Top "Music" apps:
# ...

# %% [markdown]
# Mesmo que nosso objetivo seja encontrar categorias populares, o número médio de classificações nas acima analisadas (navegação, redes sociais e música) parece estar distorcido por alguns poucos aplicativos que possuem centenas de milhares de classificações de usuários, enquanto que outros aplicativos dificilmente ultrapassem o limite de 10.000 classificações. Poderíamos ter uma imagem melhor removendo esses aplicativos extremamente populares para cada gênero e refazendo as médias, mas deixaremos esse nível de detalhe para outro momento.
#
# Os aplicativos de outra categoria bastante popular, `'Reference'`, têm em média 74.942 classificações de usuários, mas isto se deve majoritariamente à presença dos itens `'Bible'` e `'Dictionary.com'`:

# %%
ref_apps = []  # stores names and ratings for each app in this category
number_ref_apps = 0  # number of apps in this category
sum_ref_ratings = 0  # sum of total ratings

book_apps = []
number_book_apps = 0
sum_book_ratings = 0

for app in ios_final:
    name = app[1]
    ratings = int(app[5])
    genre = app[-5]
    
    if genre == 'Reference':
        number_ref_apps += 1
        sum_ref_ratings += ratings
        ref_apps.append((ratings, name))
    elif genre == 'Book':
        number_book_apps += 1
        sum_book_ratings += ratings
        book_apps.append((ratings, name))
        
print('Número de aplicativos da categoria \"Reference\":', number_ref_apps)
print('Número total de classificações da categoria \"Reference\":', sum_ref_ratings)
print('Aplicativos da categoria \"Reference\":')

for item in sorted(ref_apps, reverse=True):
    print('{}: {:,}'.format(item[1], item[0]))
    
print('=' * 40)

print('Número de aplicativos da categoria \"Book\":', number_book_apps)
print('Número total de classificações da categoria \"Book\":', sum_book_ratings)
print('Aplicativos da categoria \"Book\":')

for item in sorted(book_apps, reverse=True):
    print('{}: {:,}'.format(item[1], item[0]))
# Out:
# Número de aplicativos da categoria "Reference": 18
# Número total de classificações da categoria "Reference": 1348958
# Aplicativos da categoria "Reference":
# Bible: 985,920
# Dictionary.com Dictionary & Thesaurus: 200,047
# Dictionary.com Dictionary & Thesaurus for iPad: 54,175
# Google Translate: 26,786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran: 18,418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition: 17,588
# Merriam-Webster Dictionary: 16,849
# Night Sky: 12,122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE): 8,535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools: 4,693
# GUNS MODS for Minecraft PC Edition - Mods Tools: 1,497
# Guides for Pokémon GO - Pokemon GO News and Cheats: 826
# WWDC: 762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free: 718
# VPN Express: 14
# Real Bike Traffic Rider Virtual Reality Glasses: 8
# ...

# %% [markdown]
# Este nicho, entretanto, possui bastante potencial. Combiná-lo com as ideias de *gameficação*, presente em boa parte dos aplicativos da *App Store*, e com o alto interesse por aplicativos das categorias `'Weather'`, `'Food & Drink'` e `'Finance'` nos sugere outro perfil promissor de aplicativo a ser desenvolvido.
#
# ### 7.2. Análise da Google Play
#
# Como mencionado no início deste tópico, o conjunto de dados da *Google Play* possui uma coluna para indicar o número de instalações. Entretanto, ele possui alguns problemas. O primeiro deles é ser vago demais; não há precisão quanto ao número real de instalações, apenas uma classificação dentro de categorias:

# %%
display_freq_table(extract(android_final, 5), 'google play number of installs')
# Out:
# --------------------------------------------------
#           GOOGLE PLAY NUMBER OF INSTALLS
#       (column | number of apps | % of total)
# --------------------------------------------------
# 1,000,000+                            1394  15.73%
# 100,000+                              1024  11.55%
# 10,000,000+                            935  10.55%
# 10,000+                                904  10.20%
# 1,000+                                 744  8.39%
# 100+                                   613  6.92%
# 5,000,000+                             605  6.83%
# 500,000+                               493  5.56%
# 50,000+                                423  4.77%
# 5,000+                                 400  4.51%
# 10+                                    314  3.54%
# 500+                                   288  3.25%
# 50,000,000+                            204  2.30%
# 100,000,000+                           189  2.13%
# 50+                                    170  1.92%
# ...

# %% [markdown]
# Pela análise dos dados, não é possível saber se `10,000+` representa 10.000, 20.000 ou 33.425 instalações, e assim por diante. Entretanto, para nossos propósitos de análise, isto não nos parece um problema tão grande, tendo em vista que precisamos de uma ideia dos tipos de aplicativos que atraem mais usuários, ao invés de um número preciso de instalações.
#
# O segundo problema encontrado para a análise desses dados diz respeito à sua formatação, incluindo `,` e `+` ao final. Para realizar cálculos com estes valores, precisaremos remover estes caracteres antes de realizar a conversão entre os tipos `string` e `float`.

# %%
# extracts categories from android dataset and generates a freq. table from it
categories_android = freq_table(extract(android_final, 1))

# initialize an empty list which will contain all avg installs by category
categories_list = list()

# main loop: loop through each category in categories list
for category in categories_android:

    total = 0  # total number of installs
    len_category = 0  # total number of apps

    # secondary loop: now, loop through all apps in android dataset
    for app in android_final:

        # fetch the category of this app
        category_app = app[1]

        # check if this category is the same as the category of the main loop
        if category_app == category:

            # fetch the no. of installs of this app
            n_installs = app[5]

            # removes ',' and '+' symbols from installs number
            n_installs = n_installs.replace(',', '')
            n_installs = n_installs.replace('+', '')

            # increase total of installs and number of apps
            total += float(n_installs)
            len_category += 1

    # calculates the average number of installs
    avg_n_installs = total / len_category

    # append tuple(installs, category) to categories_list
    # this awkward order will be useful to simplify sorting
    tuple_installs_category = (avg_n_installs, category.replace('_', ' '))
    categories_list.append(tuple_installs_category)

# print list of categories, sorted descending by average number of installs
for key in sorted(categories_list, reverse=True):
    print('{}: {:,.2f}'.format(key[1], key[0]))
# Out:
# COMMUNICATION: 38,456,119.17
# VIDEO PLAYERS: 24,727,872.45
# SOCIAL: 23,253,652.13
# PHOTOGRAPHY: 17,840,110.40
# PRODUCTIVITY: 16,787,331.34
# GAME: 15,588,015.60
# TRAVEL AND LOCAL: 13,984,077.71
# ENTERTAINMENT: 11,640,705.88
# TOOLS: 10,801,391.30
# NEWS AND MAGAZINES: 9,549,178.47
# BOOKS AND REFERENCE: 8,767,811.89
# SHOPPING: 7,036,877.31
# PERSONALIZATION: 5,201,482.61
# WEATHER: 5,074,486.20
# HEALTH AND FITNESS: 4,188,821.99
# MAPS AND NAVIGATION: 4,056,941.77
# FAMILY: 3,695,641.82
# SPORTS: 3,638,640.14
# ART AND DESIGN: 1,986,335.09
# FOOD AND DRINK: 1,924,897.74
# EDUCATION: 1,833,495.15
# BUSINESS: 1,712,290.15
# LIFESTYLE: 1,437,816.27
# FINANCE: 1,387,692.48
# HOUSE AND HOME: 1,331,540.56
# DATING: 854,028.83
# COMICS: 817,657.27
# AUTO AND VEHICLES: 647,317.82
# LIBRARIES AND DEMO: 638,503.73
# PARENTING: 542,603.62
# BEAUTY: 513,151.89
# EVENTS: 253,542.22
# MEDICAL: 120,550.62

# %% [markdown]
# Aplicativos de comunicação, em média, possuem o maior número médio de instalações por categoria: **38.456.119,17**. Entretanto, este número é bastante inflado pela presença de grandes players como *WhatsApp Messenger*, *Facebook Messenger*, *Skype*, *Google Chrome*, *Gmail* e *Hangouts*, todos no intervalo de `'1,000,000,000+'` instalações:

# %%
print('Communication apps in 1,000,000,000+ installs range:')
for app in android_final:
    if app[1] == 'COMMUNICATION' and app[5] == '1,000,000,000+':
        print(app[0], ':', app[5])
# Out:
# Communication apps in 1,000,000,000+ installs range:
# WhatsApp Messenger : 1,000,000,000+
# Messenger – Text and Video Chat for Free : 1,000,000,000+
# Skype - free IM & video calls : 1,000,000,000+
# Google Chrome: Fast & Secure : 1,000,000,000+
# Gmail : 1,000,000,000+
# Hangouts : 1,000,000,000+

# %% [markdown]
# As categorias `'VIDEO PLAYERS'`, `'SOCIAL'` e `'PHOTOGRAPHY'`, bastante populares, também possuem alguns grandes *players* que elevam de sobremaneira sua avaliação média, de tal forma que disputar espaço neste terreno é mais desafiador e contraria nossa proposta com este projeto:

# %%
video_above_500 = []
social_above_500 = []
photo_above_500 = []

for app in android_final:
    category = app[1]
    ratings = float(app[5].replace(',', '').replace('+', ''))
    string_to_append = app[0] + ': ' + app[5]
    
    if ratings >= 500000000:
        if category == 'VIDEO_PLAYERS':
            video_above_500.append(string_to_append)
        elif category == 'SOCIAL':
            social_above_500.append(string_to_append)
        elif category == 'PHOTOGRAPHY':
            photo_above_500.append(string_to_append)

print('Video player apps above 500,000,000+ installs:')
print(video_above_500)
print('\nSocial apps above 500,000,000+ installs:')
print(social_above_500)
print('\nPhotography player apps above 500,000,000+ installs:')
print(photo_above_500)
# Out:
# Video player apps above 500,000,000+ installs:
# ['YouTube: 1,000,000,000+', 'Google Play Movies & TV: 1,000,000,000+', 'MX Player: 500,000,000+']
#
# Social apps above 500,000,000+ installs:
# ['Facebook: 1,000,000,000+', 'Facebook Lite: 500,000,000+', 'Google+: 1,000,000,000+', 'Instagram: 1,000,000,000+', 'Snapchat: 500,000,000+']
#
# Photography player apps above 500,000,000+ installs:
# ['Google Photos: 1,000,000,000+']

# %% [markdown]
# Analisemos, então, os aplicativos das categorias `'PRODUCTIVITY'` e `'BOOKS AND REFERENCE'`:

# %%
productivity_apps = []
books_apps = []

for app in android_final:
    name = app[0]
    genre = app[1]
    installs = int(app[5].replace(',', '').replace('+', ''))
    tuple_to_append = (installs, name)
    
    if genre == 'PRODUCTIVITY':
        productivity_apps.append(tuple_to_append)
    elif genre == 'BOOKS_AND_REFERENCE':
        books_apps.append(tuple_to_append)
        
print('Aplicativos mais baixados da categoria \"PRODUCTIVITY\":')
for item in sorted(productivity_apps[:20], reverse=True):
    print('{}: {:,}'.format(item[1], item[0]))

print('=' * 40)

print('Aplicativos mais baixados da categoria \"BOOKS AND REFERENCES\":')
for item in sorted(books_apps[:20], reverse=True):
    print('{}: {:,}'.format(item[1], item[0]))
# Out:
# Aplicativos mais baixados da categoria "PRODUCTIVITY":
# Microsoft Word: 500,000,000
# Microsoft Outlook: 100,000,000
# Microsoft OneNote: 100,000,000
# Microsoft OneDrive: 100,000,000
# Google Keep: 100,000,000
# ES File Explorer File Manager: 100,000,000
# Calculator - unit converter: 50,000,000
# QR Scanner & Barcode Scanner 2018: 10,000,000
# Metro name iD: 10,000,000
# HTC File Manager: 10,000,000
# Google PDF Viewer: 10,000,000
# Google Assistant: 10,000,000
# Chrome Beta: 10,000,000
# All-In-One Toolbox: Cleaner, Booster, App Manager: 10,000,000
# AVG Cleaner – Speed, Battery & Memory Booster: 10,000,000
# ASUS SuperNote: 10,000,000
# My Claro Peru: 5,000,000
# Archos File Manager: 5,000,000
# Power Booster - Junk Cleaner & CPU Cooler & Boost: 1,000,000
# MyMTN: 1,000,000
# ...
# Aplicativos mais baixados da categoria "BOOKS AND REFERENCES":
# Google Play Books: 1,000,000,000
# Wikipedia: 10,000,000
# FBReader: Favorite Book Reader: 10,000,000
# Cool Reader: 10,000,000
# ...

# %% [markdown]
# Os aplicativos mais baixados da categoria `'PRODUCTIVITY'` são, em sua maioria, utilitários de escritório (*Microsoft Word*, *Microsoft Outlook*, *Microsoft OneNote*, etc.) e aplicativos de gerenciamento das funções do smartphone (*ES File Explorer File Manager*, *All-In-One Toolbox*, *AVG Cleaner*, etc.). Este perfil não nos parece interessante, uma vez que o desenvolvimento deste tipo de aplicativo requer muito tempo e recursos financeiros.
#
# Por outro lado, a categoria `'BOOKS AND REFERENCES'`, apesar de inflada pelo massivo número de instalações do aplicativo *Google Play Books* (instalado por padrão na maior parte dos smartphones com sistema *Android*, ele possui cem vezes mais downloads do que o próximo item da lista) se mostra promissora. Quando analisamos em conjunto os datasets `ios_final` e `android_final`, percebemos que há um grande interesse nessa área, principalmente por livros de receitas.
#
# ## Conclusões
#
# Ao longo deste documento, vimos que há categorias de aplicativos bastante populares, tais como *Redes Sociais*, *Música*, *Navegação* e *Comunicação*, porém capitaneadas por grandes "carros-chefe" que conseguiram se estabelecer no mercado. Competir com estes aplicativos requer esforços que vão além do escopo deste projeto.
#
# Outras categorias, um pouco menores mas com números expressivos de instalações e reviews de usuários, despertaram nosso interesse durante a análise dos dados.
